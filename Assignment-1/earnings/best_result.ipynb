# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings("ignore")

# %%
#data is unique by gvkey and fyear
data = pd.read_csv('fundamentals_annual/fundamentals_annual.csv')

income = pd.read_csv('fundamentals_annual/income.csv')
data = data.merge(income, on = ['gvkey','fyear'],  suffixes=('', '_drop'))
data = data[[c for c in data.columns if not c.endswith('_drop')]]

shares = pd.read_csv('shares.csv')
data = data.merge(shares, on = ['gvkey','fyear'],  suffixes=('', '_drop'))
data = data[[c for c in data.columns if not c.endswith('_drop')]]
# fyear and fyrc share same values
# fdate is the date when the data is finalized for the fiscal year. Just fiscal year alone will not tell us anything.

# %%
data.drop(['consol','popsrc','indfmt'],axis=1,inplace=True) #same for all rows


data.sort_values(by=['gvkey','fyear','fyr'],inplace=True) #sort by gvkey and fyear

#drop columns with constant value 
for i in data.columns:
    if(len(data[i].unique()) == 1):
        data.drop(i, axis=1,inplace=True)
        
#drop columns with more than 10% missing values?
perc = 10.0 
min_count =  int(((100-perc)/100)*data.shape[0] + 1)
data = data.dropna( axis=1, thresh=min_count)

#drop rest row-wise
data.drop('acominc',axis=1,inplace=True)
data.dropna(inplace=True)

# %%
#methods
#1. filter by gvkey to get records for all fyear and then run a time series regression with lag variables. 
#2. Train a model with all firms in the dataset.
#3  Use datadate that falls in the previous fiscal year to predict the earnings of the company in the next year.

# %% [markdown]
# FYEAR indicates the fiscal year that the company is in at the time of DATADATE.
# Compustat it is pretty simple to understand, DATADATE gives us the annual close of fiscal period, in the case of MSFT
# (June FY) this might be 6/30/2010, and the FYEAR is 2010
#
# we can work with datadate and fyear
# fdate will give the end of the fiscal year.
# datadate will tell the date the data was recorded
# fyr and fyear together should match the month and year of datadate
#
# DATADATE is COMPUSTAT’s approximation of the fiscal period-end date, but I have seen cases where this is off a
# few days from the company’s actual fiscal year-end date in EDGAR filings because DATADATE will be the last day of the month. APDEDATE is defined by COMPUSTAT as, “This item represents the actual date the company closes accounting for the period, which can be different from the last day of the month in the period.” Both of these dates may be thought of as the Balance Sheet date one would find in the actual corporate fillings.

# %%
df = pd.DataFrame()
df[data.columns] = data[data.columns]
df.drop(['datadate','tic','conm','fyr'],axis=1,inplace=True)

# %%
#removing the look ahead bias by shifting the data
ni = df.groupby('gvkey')['ni'].shift(-1)
df['ni'] = ni
df.dropna(inplace=True)

#very high correlations between features. its expected since they are mathematically derived from each other
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4b6cf_row0_col0, #T_4b6cf_row1_col1, #T_4b6cf_row2_col2, #T_4b6cf_row3_col3, #T_4b6cf_row4_col4, #T_4b6cf_row5_col5, #T_4b6cf_row6_col6, #T_4b6cf_row7_col7, #T_4b6cf_row8_col8, #T_4b6cf_row9_col9, #T_4b6cf_row10_col10, #T_4b6cf_row11_col11, #T_4b6cf_row12_col12, #T_4b6cf_row13_col13, #T_4b6cf_row14_col14, #T_4b6cf_row15_col15, #T_4b6cf_row16_col16, #T_4b6cf_row17_col17, #T_4b6cf_row18_col18, #T_4b6cf_row19_col19, #T_4b6cf_row20_col20, #T_4b6cf_row21_col21, #T_4b6cf_row22_col22, #T_4b6cf_row23_col23 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_
{
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4b6cf_row1_col14, #T_4b6cf_row5_col1, #T_4b6cf_row17_col5, #T_4b6cf_row20_col16, #T_4b6cf_row22_col0, #T_4b6cf_row23_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4b6cf_row1_col18, #T_4b6cf_row2_col14, #T_4b6cf_row3_col14, #T_4b6cf_row17_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_4b6cf_row1_col19, #T_4b6cf_row14_col13, #T_4b6cf_row20_col3, #T_4b6cf_row20_col4, #T_4b6cf_row20_col13, #T_4b6cf_row20_col18 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_4b6cf_row1_col20, #T_4b6cf_row5_col20, #T_4b6cf_row14_col6, #T_4b6cf_row14_col15, #T_4b6cf_row14_col20, #T_4b6cf_row17_col16, #T_4b6cf_row21_col14, #T_4b6cf_row23_col20 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col0, #T_4b6cf_row17_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col1, #T_4b6cf_row4_col1, #T_4b6cf_row7_col0, #T_4b6cf_row8_col17, #T_4b6cf_row11_col1, #T_4b6cf_row13_col1, #T_4b6cf_row17_col23 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col4, #T_4b6cf_row4_col2, #T_4b6cf_row8_col10, #T_4b6cf_row11_col10, #T_4b6cf_row11_col13, #T_4b6cf_row18_col11, #T_4b6cf_row18_col16 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col5, #T_4b6cf_row7_col4, #T_4b6cf_row22_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_4b6cf_row2_col6, #T_4b6cf_row5_col16, #T_4b6cf_row8_col12, #T_4b6cf_row12_col10 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_4b6cf_row2_col7, #T_4b6cf_row7_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_4b6cf_row2_col8, #T_4b6cf_row12_col22, #T_4b6cf_row23_col19 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_4b6cf_row2_col9, #T_4b6cf_row18_col6 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_4b6cf_row2_col10, #T_4b6cf_row23_col18 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_4b6cf_row2_col11, #T_4b6cf_row2_col18, #T_4b6cf_row4_col9, #T_4b6cf_row9_col4, #T_4b6cf_row16_col12, #T_4b6cf_row19_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col12, #T_4b6cf_row5_col18, #T_4b6cf_row23_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_4b6cf_row2_col13, #T_4b6cf_row4_col15, #T_4b6cf_row8_col9, #T_4b6cf_row9_col8, #T_4b6cf_row13_col2, #T_4b6cf_row15_col4 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col15, #T_4b6cf_row4_col13, #T_4b6cf_row10_col16, #T_4b6cf_row13_col4, #T_4b6cf_row13_col18, #T_4b6cf_row15_col13, #T_4b6cf_row18_col13 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col16, #T_4b6cf_row7_col22 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col17, #T_4b6cf_row17_col13, #T_4b6cf_row17_col15 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col19, #T_4b6cf_row6_col7, #T_4b6cf_row7_col5, #T_4b6cf_row8_col23 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_4b6cf_row2_col20, #T_4b6cf_row14_col8 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_4b6cf_row2_col21, #T_4b6cf_row21_col23 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_4b6cf_row2_col22, #T_4b6cf_row21_col18 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_4b6cf_row2_col23 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_4b6cf_row3_col0, #T_4b6cf_row16_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4b6cf_row3_col1, #T_4b6cf_row8_col0, #T_4b6cf_row13_col0, #T_4b6cf_row18_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_4b6cf_row3_col2 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_4b6cf_row3_col4, #T_4b6cf_row3_col16, #T_4b6cf_row4_col3, #T_4b6cf_row4_col11, #T_4b6cf_row9_col10, #T_4b6cf_row10_col9, #T_4b6cf_row11_col4 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_4b6cf_row3_col5, #T_4b6cf_row6_col23, #T_4b6cf_row12_col7, #T_4b6cf_row21_col9 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_4b6cf_row3_col6, #T_4b6cf_row18_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_4b6cf_row3_col7, #T_4b6cf_row5_col2, #T_4b6cf_row19_col23 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_4b6cf_row3_col8, #T_4b6cf_row3_col10, #T_4b6cf_row7_col19, #T_4b6cf_row8_col3, #T_4b6cf_row11_col7, #T_4b6cf_row15_col8, #T_4b6cf_row19_col22, #T_4b6cf_row22_col10, #T_4b6cf_row22_col16, #T_4b6cf_row22_col19 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_4b6cf_row3_col9, #T_4b6cf_row6_col15, #T_4b6cf_row9_col3, #T_4b6cf_row11_col12, #T_4b6cf_row15_col6 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_4b6cf_row3_col11, #T_4b6cf_row11_col3, #T_4b6cf_row15_col16, #T_4b6cf_row16_col15 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_4b6cf_row3_col12, #T_4b6cf_row4_col12, #T_4b6cf_row6_col18, #T_4b6cf_row21_col8 {
#   background-colo

# %%
def prediction(df1, components):
    df1 = df1.drop('gvkey',axis=1)
    alpha_vals = np.arange(0.01,1)
    X_train, X_test, y_train, y_test = train_test_split(df1.loc[:, df1.columns != 'ni'], df1['ni'], 
                                                        test_size=0.33, random_state=42)
    pipe = Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components= components)), 
                           ('ridge', Ridge(fit_intercept=True))])
    gsc = GridSearchCV(pipe, param_grid={ 'ridge__alpha': alpha_vals},cv=10, scoring='r2')
    gsc.fit(X_train, y_train)
    y_pred = gsc.predict(X_test)
    RMSE = (mean_squared_error(y_test,y_pred)**(1/2))
    print(r2_score(y_test, y_pred))
    print(RMSE)

# %%
#passing the entire dataframe for scaling, PCA and prediction
prediction(df, 11)
# Out:
# 0.4659481037899208
# 599.4174740803446

# %%
#using the between estimates regression method. 
be = df.groupby('gvkey').mean()
be.reset_index(inplace=True)
prediction(be,11)
# Out:
# 0.879622175311344
# 108.60927948936948

# %%
be['ni'].std()
# Out:
# 357.6582742779234

# %%
#analysis of PCA
def PCA_analysis(temp, components):
    pca = PCA()
    dataset = pd.DataFrame()

    #checking correlation of target variable with different principal components.
    transformed = pca.fit_transform(temp.drop('ni',axis=1))
    for i in range(0, len(transformed[0])):
        dataset[i] = transformed[:,i]
        print(i, temp['ni'].corr(dataset[i]))

    pca = PCA(n_components=components)
    transformed = pca.fit_transform(temp.drop('ni',axis=1))
    print(pca.explained_variance_ratio_)
    print(sum(pca.explained_variance_ratio_))

# %% [markdown]
# ***
