# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings("ignore")

# %%
#data is unique by gvkey and fyear
data = pd.read_csv('fundamentals_annual.csv')

fyear = pd.read_csv('income.csv')
data = data.merge(fyear, on = ['gvkey','fyear'],  suffixes=('', '_drop'))
data = data[[c for c in data.columns if not c.endswith('_drop')]]

# fyear and fyrc share same values
# fdate is the date when the data is finalized for the fiscal year. Just fiscal year alone will not tell us anything.

# %%
data.drop(['consol','popsrc','indfmt'],axis=1,inplace=True) #same for all rows
data.drop(['dvpd','opiti','tii','uopi'], axis=1, inplace=True) #NaN values only
data.drop(['gld','gleps','glp'], axis=1, inplace=True) #more than 90% values are NaN

data.sort_values(by=['gvkey','fyear','fyr'],inplace=True) #sort by gvkey and fyear

#drop columns with constant value 
for i in data.columns:
    if(len(data[i].unique()) == 1):
        data.drop(i, axis=1,inplace=True)
        
#drop columns with more than 10% missing values?
perc = 10.0 
min_count =  int(((100-perc)/100)*data.shape[0] + 1)
data = data.dropna( axis=1, thresh=min_count)
data

# %%
#methods
#1. filter by gvkey to get records for all fyear and then run a time series regression with lag variables. 
#2. Train a model with all firms in the dataset.
#3  Use datadate that falls in the previous fiscal year to predict the earnings of the company in the next year.

# %% [markdown]
# FYEAR indicates the fiscal year that the company is in at the time of DATADATE.
# Compustat it is pretty simple to understand, DATADATE gives us the annual close of fiscal period, in the case of MSFT
# (June FY) this might be 6/30/2010, and the FYEAR is 2010
#
# we can work with datadate and fyear
# fdate will give the end of the fiscal year.
# datadate will tell the date the data was recorded
# fyr and fyear together should match the month and year of datadate
#
# DATADATE is COMPUSTAT’s approximation of the fiscal period-end date, but I have seen cases where this is off a
# few days from the company’s actual fiscal year-end date in EDGAR filings because DATADATE will be the last day of the month. APDEDATE is defined by COMPUSTAT as, “This item represents the actual date the company closes accounting for the period, which can be different from the last day of the month in the period.” Both of these dates may be thought of as the Balance Sheet date one would find in the actual corporate fillings.

# %%
#why is there such a wide gap between the two dates?
(pd.to_datetime(data['fdate']) - pd.to_datetime(data['datadate'])).sort_values(ascending =False)
# Out:
# 1806   1850 days
# 1757   1773 days
# 1472   1767 days
# 1817   1609 days
# 1776   1602 days
#           ...
# 2717         NaT
# 2718         NaT
# 2719         NaT
# 2720         NaT
# 2721         NaT
# Length: 2761, dtype: timedelta64[ns]

# %%
df = pd.DataFrame()
df['gvkey'] = data['gvkey']
df[data.columns[6:]] = data[data.columns[6:]]

#fill missing values using forward fill and backward fill and take average
#what this means is that the asset value in that year lied between the the asset value the year before and the one
#the year after
temp = df.groupby('gvkey').fillna(method='ffill')
temp = temp.fillna(0)
temp2 = df.groupby('gvkey').fillna(method='bfill')
temp2 = temp2.fillna(0)

cols = data.columns[6:]
for i in cols:
    df[i] = (temp[i] + temp2[i])//2

#another way of filling in missing values could be just taking a percentage for example, income is 20% of assets etc
#df.isna().sum()

# %%
#removing the look ahead bias by shifting the data
ni = df.groupby('gvkey')['ni'].shift(-1)
df['ni'] = ni
df.dropna(inplace=True)

#very high correlations between features. its expected since they are mathematically derived from each other
df[cols].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_98f2c_row0_col0, #T_98f2c_row1_col1, #T_98f2c_row2_col2, #T_98f2c_row3_col3, #T_98f2c_row4_col4, #T_98f2c_row5_col5, #T_98f2c_row6_col6, #T_98f2c_row7_col7, #T_98f2c_row8_col8, #T_98f2c_row9_col9, #T_98f2c_row10_col10, #T_98f2c_row11_col11, #T_98f2c_row12_col12, #T_98f2c_row13_col13, #T_98f2c_row14_col14, #T_98f2c_row15_col15, #T_98f2c_row16_col16, #T_98f2c_row17_col17, #T_98f2c_row18_col18, #T_98f2c_row19_col19, #T_98f2c_row20_col20, #T_98f2c_row21_col21 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_98f2c_row0_col1, #T_98f2c_row0_col2, #T_98f2c_row0_col3, #T_98f2c_row0_col4, #T_98f2c_row0_col5, #T_98f2c_row0_col7, #T_98f2c_row0_col8, #T_98f2c_row0_col9, #T_98f2c_row0_col10, #T_98f2c_row0_col11, #T_98f2c_row0_col12, #T_98f2c_row0_col14, #T_98f2c_row0_col15, #T_98f2c_row0_col16, #T_98f2c_row0_col17, #T_98f2c_row0_col18, #T_98f2c_row1_col0, #T_98f2c_row11_col19, #T_98f2c_row12_col0, #T_98f2c_row16_col6, #T_98f2c_row19_col13, #T_98f2c_row19_col20, #T_98f2c_row19_col21 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_98f2c_row0_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_98f2c_row0_col13, #T_98f2c_row3_col0, #T_98f2c_row12_col13 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_98f2c_row0_col19, #T_98f2c_row0_col21, #T_98f2c_row18_col19, #T_98f2c_row20_col16 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_98f2c_row0_col20, #T_98f2c_row8_col0, #T_98f2c_row17_col16 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col2, #T_98f2c_row2_col1, #T_98f2c_row7_col8, #T_98f2c_row10_col14 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col3, #T_98f2c_row3_col1, #T_98f2c_row7_col21, #T_98f2c_row10_col12, #T_98f2c_row21_col7 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col4, #T_98f2c_row17_col21 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_98f2c_row1_col5, #T_98f2c_row1_col8, #T_98f2c_row15_col18, #T_98f2c_row17_col5, #T_98f2c_row18_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_98f2c_row1_col7, #T_98f2c_row20_col3, #T_98f2c_row20_col17 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_98f2c_row1_col9, #T_98f2c_row17_col4, #T_98f2c_row21_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_98f2c_row1_col10, #T_98f2c_row7_col6, #T_98f2c_row9_col7, #T_98f2c_row15_col1, #T_98f2c_row15_col5 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col11, #T_98f2c_row12_col7 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_98f2c_row1_col12, #T_98f2c_row3_col14, #T_98f2c_row12_col1, #T_98f2c_row14_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col13, #T_98f2c_row2_col13, #T_98f2c_row16_col21 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col14, #T_98f2c_row5_col10, #T_98f2c_row8_col14, #T_98f2c_row10_col5, #T_98f2c_row12_col3 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col15, #T_98f2c_row3_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col16 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_98f2c_row1_col17, #T_98f2c_row6_col7 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col18, #T_98f2c_row6_col12, #T_98f2c_row12_col11, #T_98f2c_row15_col21 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_98f2c_row1_col19 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_98f2c_row1_col20, #T_98f2c_row13_col15, #T_98f2c_row16_col15 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_98f2c_row1_col21 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_98f2c_row2_col0, #T_98f2c_row16_col20 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col3, #T_98f2c_row8_col10, #T_98f2c_row10_col3, #T_98f2c_row15_col2 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col4, #T_98f2c_row5_col7, #T_98f2c_row20_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_98f2c_row2_col5, #T_98f2c_row7_col10, #T_98f2c_row17_col8, #T_98f2c_row21_col8 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col6, #T_98f2c_row20_col9 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_98f2c_row2_col7, #T_98f2c_row3_col4, #T_98f2c_row4_col17, #T_98f2c_row11_col7, #T_98f2c_row14_col7, #T_98f2c_row18_col21 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_98f2c_row2_col8, #T_98f2c_row11_col5, #T_98f2c_row11_col10, #T_98f2c_row14_col5 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col9, #T_98f2c_row7_col11 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_98f2c_row2_col10, #T_98f2c_row2_col14, #T_98f2c_row14_col2, #T_98f2c_row14_col15 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col11, #T_98f2c_row6_col18, #T_98f2c_row7_col1, #T_98f2c_row14_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_98f2c_row2_col12, #T_98f2c_row10_col15, #T_98f2c_row12_col2, #T_98f2c_row15_col10 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col15, #T_98f2c_row9_col8, #T_98f2c_row10_col8, #T_98f2c_row15_col3, #T_98f2c_row17_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col16, #T_98f2c_row14_col16, #T_98f2c_row18_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_98f2c_row2_col17, #T_98f2c_row14_col12 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col18, #T_98f2c_row4_col5, #T_98f2c_row9_col12, #T_98f2c_row15_col4, #T_98f2c_row21_col10 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_98f2c_row2_col19, #T_98f2c_row19_col16 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_98f2c_row2_col20, #T_98f2c_row19_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_98f2c_row2_col21 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_98f2c_row3_col2, #T_98f2c_row8_col15 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col6 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_98f2c_row3_col7, #T_98f2c_row5_col18, #T_98f2c_row6_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_98f2c_row3_col8, #T_98f2c_row5_col11, #T_98f2c_row9_col3, #T_98f2c_row14_col9 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col9, #T_98f2c_row7_col2, #T_98f2c_row7_col14, #T_98f2c_row9_col2, #T_98f2c_row18_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col10, #T_98f2c_row15_col8 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col11, #T_98f2c_row11_col17, #T_98f2c_row20_col21, #T_98f2c_row21_col20 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_98f2c_row3_col12, #T_98f2c_row12_col14, #T_98f2c_row14_col1, #T_98f2c_row17_col12 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col13 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col15, #T_98f2c_row8_col9 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col16, #T_98f2c_row9_col0, #T_98f2c_row13_col11, #T_98f2c_row16_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_98f2c_row3_col17, #T_98f2c_row12_col15 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col18, #T_98f2c_row7_col20, #T_98f2c_row15_col6 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_98f2c_row3_col19, #T_98f2c_row16_col19 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_98f2c_row3_col20, #T_98f2c_row7_col0, #T_98f2c_row16_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_98f2c_row3_col21, #T_98f2c_row20_col5, #T_98f2c_row20_col11 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_98f2c_row4_col0, #T_98f2c_row16_col11 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_98f2c_row4_col1, #T_98f2c_row6_col5, #T_98f2c_row18_col5, #T_98f2c_row20_col7 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_98f2c_row4_col2, #T_98f2c_row21_col18 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_98f2c_row4_col3, #T_98f2c_row7_col3, #T_98f2c_row18_col3 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_98f2c_row4_col6, #T_98f2c_row20_col12 {
#   background-color: #f2cbb7;
#   co

# %%
def prediction(df1, components):
    df1 = df1.drop('gvkey',axis=1)
    alpha_vals = np.arange(0.01,1)
    X_train, X_test, y_train, y_test = train_test_split(df1.loc[:, df1.columns != 'ni'], df1['ni'], 
                                                        test_size=0.33, random_state=42)
    pipe = Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components= components)), 
                           ('ridge', Ridge(fit_intercept=True))])
    gsc = GridSearchCV(pipe, param_grid={ 'ridge__alpha': alpha_vals},cv=10, scoring='r2')
    gsc.fit(X_train, y_train)
    y_pred = gsc.predict(X_test)
    RMSE = (mean_squared_error(y_test,y_pred)**(1/2))
    print(r2_score(y_test, y_pred))
    print(RMSE)

# %%
#passing the entire dataframe for scaling, PCA and prediction
prediction(df, 11)
# Out:
# 0.4712088880125791
# 525.8314053295571

# %%
#using the between estimates regression method. 
be = df.groupby('gvkey').mean()
be.reset_index(inplace=True)
prediction(be,11)
# Out:
# 0.9509331763239879
# 66.38957376898622

# %%
be['ni'].std()
# Out:
# 353.019727003478

# %%
#analysis of PCA
def PCA_analysis(temp, components):
    pca = PCA()
    dataset = pd.DataFrame()

    #checking correlation of target variable with different principal components.
    transformed = pca.fit_transform(temp.drop('ni',axis=1))
    for i in range(0, len(transformed[0])):
        dataset[i] = transformed[:,i]
        print(i, temp['ni'].corr(dataset[i]))

    pca = PCA(n_components=components)
    transformed = pca.fit_transform(temp.drop('ni',axis=1))
    print(pca.explained_variance_ratio_)
    print(sum(pca.explained_variance_ratio_))
