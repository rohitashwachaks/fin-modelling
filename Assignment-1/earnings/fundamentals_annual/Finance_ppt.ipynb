# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#data is unique by gvkey and fyear
data = pd.read_csv('fundamentals_annual.csv')
data.head()
# Out:
#    gvkey    datadate  fyear indfmt consol popsrc datafmt   tic  \
# 0   2080  11/30/2000   2000   INDL      C      D     STD  BSET
# 1   2080  11/30/2001   2001   INDL      C      D     STD  BSET
# 2   2080  11/30/2002   2002   INDL      C      D     STD  BSET
# 3   2080  11/30/2003   2003   INDL      C      D     STD  BSET
# 4   2080  11/30/2004   2004   INDL      C      D     STD  BSET
#
#                      conm curcd  ...  txdbcl   txdi    txp    txt  uopi  \
# 0  BASSETT FURNITURE INDS   USD  ...     NaN  1.708  0.000  4.671   NaN
# 1  BASSETT FURNITURE INDS   USD  ...     NaN -0.824  0.000 -1.042   NaN
# 2  BASSETT FURNITURE INDS   USD  ...     NaN  2.215  0.000  2.369   NaN
# 3  BASSETT FURNITURE INDS   USD  ...     NaN -1.154  1.530  0.462   NaN
# 4  BASSETT FURNITURE INDS   USD  ...     NaN  1.875  0.682  2.641   NaN
#
#    costat  ggroup   sic  spcindcd  spcseccd
# 0       A    2520  2511     315.0     976.0
# 1       A    2520  2511     315.0     976.0
# 2       A    2520  2511     315.0     976.0
# 3       A    2520  2511     315.0     976.0
# 4       A    2520  2511     315.0     976.0
#
# [5 rows x 49 columns]

# %%
fyear = pd.read_csv('income.csv')
fyear.head()
# Out:
#    gvkey    datadate  fyear indfmt consol popsrc datafmt curcd      ni  \
# 0   2080  11/30/2000   2000   INDL      C      D     STD   USD  10.032
# 1   2080  11/30/2001   2001   INDL      C      D     STD   USD  -2.642
# 2   2080  11/30/2002   2002   INDL      C      D     STD   USD   6.741
# 3   2080  11/30/2003   2003   INDL      C      D     STD   USD  -0.470
# 4   2080  11/30/2004   2004   INDL      C      D     STD   USD   8.209
#
#        pi   txpd costat  ggroup
# 0  15.067  1.994      A    2520
# 1  -3.684  1.485      A    2520
# 2   9.110  0.350      A    2520
# 3   4.867 -3.366      A    2520
# 4  10.850  1.700      A    2520

# %%
data = data.merge(fyear, on = ['gvkey','fyear'],  suffixes=('', '_drop'))
data = data[[c for c in data.columns if not c.endswith('_drop')]]

# fyear and fyrc share same values
# fdate is the date when the data is finalized for the fiscal year. Just fiscal year alone will not tell us anything.

# %%
data.drop(['consol','popsrc','indfmt'],axis=1,inplace=True) #same for all rows
data.drop(['dvpd','opiti','tii','uopi'], axis=1, inplace=True) #NaN values only
data.drop(['gld','gleps','glp'], axis=1, inplace=True) #more than 90% values are NaN

# %%
#drop columns with constant value 
for i in data.columns:
    if(len(data[i].unique()) == 1):
        print(f'Dropped: {i}')
        data.drop(i, axis=1,inplace=True)
data.head()
# Out:
# Dropped: datafmt
# Dropped: curcd
# Dropped: costat
# Dropped: ggroup
#    gvkey    datadate  fyear   tic                    conm  fyr fdate  acominc  \
# 0   2080  11/30/2000   2000  BSET  BASSETT FURNITURE INDS   11   NaN      NaN
# 1   2080  11/30/2001   2001  BSET  BASSETT FURNITURE INDS   11   NaN    3.047
# 2   2080  11/30/2002   2002  BSET  BASSETT FURNITURE INDS   11   NaN    1.551
# 3   2080  11/30/2003   2003  BSET  BASSETT FURNITURE INDS   11   NaN    2.531
# 4   2080  11/30/2004   2004  BSET  BASSETT FURNITURE INDS   11   NaN    2.818
#
#        act      ap  ...  txdbcl   txdi    txp    txt   sic  spcindcd  \
# 0  136.875  20.310  ...     NaN  1.708  0.000  4.671  2511     315.0
# 1   98.602  15.010  ...     NaN -0.824  0.000 -1.042  2511     315.0
# 2  102.966  17.738  ...     NaN  2.215  0.000  2.369  2511     315.0
# 3  100.697  15.127  ...     NaN -1.154  1.530  0.462  2511     315.0
# 4  102.677  19.948  ...     NaN  1.875  0.682  2.641  2511     315.0
#
#    spcseccd      ni      pi   txpd
# 0     976.0  10.032  15.067  1.994
# 1     976.0  -2.642  -3.684  1.485
# 2     976.0   6.741   9.110  0.350
# 3     976.0  -0.470   4.867 -3.366
# 4     976.0   8.209  10.850  1.700
#
# [5 rows x 38 columns]

# %%
#fdate or the final date is the date the data is finalized for that period. 
#what is datadate?
#FYEAR indicates the fiscal year that the company is in at the time of DATADATE.
#Compustat it is pretty simple to understand, DATADATE gives us the annual close of fiscal period, in the case of MSFT
#(June FY) this might be 6/30/2010, and the FYEAR is 2010

# %%
#we can work with datadate and fyear
#fdate will give the end of the fiscal year. 
#datadate will tell the date the data was recorded
#fyr and fyear together should match the month and year of datadate

# %%
#methods
#1. filter by gvkey to get records for all fyear and then run a time series regression with lag variables. 
#2. Train a model with all firms in the dataset.

# %% [markdown]
# DATADATE is COMPUSTAT’s approximation of the fiscal period-end date, but I have seen cases where this is off a
# few days from the company’s actual fiscal
# year-end date in EDGAR filings because DATADATE will be the last day of the month. APDEDATE is defined by
# COMPUSTAT as, “This item represents the actual date the company closes accounting for the period, which can
# be different from the last day of the month in the period.” Both of these dates may be thought of as the
# Balance Sheet date one would find in the actual corporate fillings.

# %%
#how to deal with missing values? what should be the threshold for dropping columns missing values? 
data
# Out:
#        gvkey    datadate  fyear    tic                    conm  fyr  \
# 0       2080  11/30/2000   2000   BSET  BASSETT FURNITURE INDS   11
# 1       2080  11/30/2001   2001   BSET  BASSETT FURNITURE INDS   11
# 2       2080  11/30/2002   2002   BSET  BASSETT FURNITURE INDS   11
# 3       2080  11/30/2003   2003   BSET  BASSETT FURNITURE INDS   11
# 4       2080  11/30/2004   2004   BSET  BASSETT FURNITURE INDS   11
# ...      ...         ...    ...    ...                     ...  ...
# 2756  271841  12/31/2016   2016  GFASY               GAFISA SA   12
# 2757  271841  12/31/2017   2017  GFASY               GAFISA SA   12
# 2758  271841  12/31/2018   2018  GFASY               GAFISA SA   12
# 2759  271841  12/31/2019   2019  GFASY               GAFISA SA   12
# 2760  271841  12/31/2020   2020  GFASY               GAFISA SA   12
#
#            fdate  acominc       act      ap  ...  txdbcl    txdi     txp  \
# 0            NaN      NaN   136.875  20.310  ...     NaN   1.708   0.000
# 1            NaN    3.047    98.602  15.010  ...     NaN  -0.824   0.000
# 2            NaN    1.551   102.966  17.738  ...     NaN   2.215   0.000
# 3            NaN    2.531   100.697  15.127  ...     NaN  -1.154   1.530
# 4            NaN    2.818   102.677  19.948  ...     NaN   1.875   0.682
# ...          ...      ...       ...     ...  ...     ...     ...     ...
# 2756  06/05/2017    0.000  1045.186  87.455  ...     0.0  27.468  15.936
# 2757  06/30/2018    0.000   523.210  77.026  ...     0.0  -7.829  14.018
# 2758  12/05/2019    0.000   438.044  60.239  ...     0.0  -6.483  14.795
# 2759  07/13/2020    0.000   450.252  52.981  ...     0.0  -9.269  17.382
# 2760  05/09/2021    0.000   483.653  87.226  ...     0.0   0.000  16.515
#
#          txt   sic  spcindcd  spcseccd       ni       pi   txpd
# 0      4.671  2511     315.0     976.0   10.032   15.067  1.994
# 1     -1.042  2511     315.0     976.0   -2.642   -3.684  1.485
# 2      2.369  2511     315.0     976.0    6.741    9.110  0.350
# 3      0.462  2511     315.0     976.0   -0.470    4.867 -3.366
# 4      2.641  2511     315.0     976.0    8.209   10.850  1.700
# ...      ...   ...       ...       ...      ...      ...    ...
# 2756  30.764  1520       NaN       NaN -357.677 -154.291  3.296
# 2757  -6.974  1520       NaN       NaN -256.591 -293.292  0.855
# 2758  -5.618  1520       NaN       NaN -108.368 -114.438  0.865
# 2759  -8.776  1520       NaN       NaN   -6.478  -15.344  0.493
# 2760   1.447  1520       NaN       NaN  -14.554  -13.198  1.447
#
# [2761 rows x 38 columns]

# %%
#use datadate that falls in the previous fiscal year to predict the earnings of the company in the next year.

# %%
#why is there such a wide gap between the two dates?
(pd.to_datetime(data['fdate']) - pd.to_datetime(data['datadate'])).sort_values(ascending =False)
# Out:
# 1806   1850 days
# 1757   1773 days
# 1472   1767 days
# 1817   1609 days
# 1776   1602 days
#           ...
# 2717         NaT
# 2718         NaT
# 2719         NaT
# 2720         NaT
# 2721         NaT
# Length: 2761, dtype: timedelta64[ns]

# %%
data.sort_values(by=['gvkey','fyear','fyr'],inplace=True)

# %%
data.isna().sum()
# Out:
# gvkey         0
# datadate      0
# fyear         0
# tic           0
# conm          0
# fyr           0
# fdate       702
# acominc     190
# act         377
# ap           54
# at           54
# ch           88
# citotal     591
# cshpri       80
# dltt         59
# dvt          80
# ebit         57
# ebitda       71
# gp           57
# icapt        54
# invt         54
# lt           55
# opeps        80
# revt         57
# seq          54
# teq         486
# txdba       514
# txdbca      664
# txdbcl      599
# txdi        121
# txp          93
# txt          57
# sic           0
# spcindcd    700
# spcseccd    700
# ni           57
# pi           57
# txpd        292
# dtype: int64

# %%
df = data[['gvkey', 'datadate', 'fyear','fyr', 'acominc','act', 'ap', 'at', 'ch', 'citotal', 'cshpri', 'dltt', 'dvt', 'ebit','ebitda', 'gp', 'icapt', 'invt', 'lt', 'opeps', 'revt', 'seq','txdi', 'txp', 'txt', 'sic','ni','pi','txpd']]
#fill missing values using forward fill and backward fill and take average
#what this means is that the asset value in that year lied between the the asset value the year before and the one
#the year after
temp = df.groupby('gvkey').fillna(method='ffill')
temp = temp.fillna(0)
temp2 = df.groupby('gvkey').fillna(method='bfill')
temp2 = temp2.fillna(0)

cols = ['acominc','act', 'ap', 'at', 'ch', 'citotal', 'cshpri', 'dltt', 'dvt', 'ebit','ebitda', 'gp', 'icapt', 'invt', 'lt', 'opeps', 'revt', 'seq','txdi', 'txp', 'txt', 'sic','ni','pi','txpd']
for i in cols:
    df[i] = (temp[i] + temp2[i])//2
    
df.isna().sum()
# Out:
# /var/folders/y3/v6fyb_rs72bcn7ftc3lvwvmw0000gn/T/ipykernel_25792/3217801653.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = (temp[i] + temp2[i])//2
# gvkey       0
# datadate    0
# fyear       0
# fyr         0
# acominc     0
# act         0
# ap          0
# at          0
# ch          0
# citotal     0
# cshpri      0
# dltt        0
# dvt         0
# ebit        0
# ebitda      0
# gp          0
# icapt       0
# invt        0
# lt          0
# opeps       0
# revt        0
# seq         0
# txdi        0
# txp         0
# txt         0
# sic         0
# ni          0
# pi          0
# txpd        0
# dtype: int64

# %%
temp = df[['acominc', 'act', 'ap', 'at', 'ch','citotal', 'cshpri', 'dltt', 'dvt', 'ebit', 'ebitda', 'gp', 'icapt','invt', 'lt', 'opeps', 'revt', 'seq', 'txdi', 'txp', 'txt', 'sic','ni','pi','txpd']]

# %%
#very high correlations between features. its expected since they are mathematically derived from each other
temp.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d904c_row0_col0, #T_d904c_row1_col1, #T_d904c_row2_col2, #T_d904c_row3_col3, #T_d904c_row4_col4, #T_d904c_row5_col5, #T_d904c_row6_col6, #T_d904c_row7_col7, #T_d904c_row8_col8, #T_d904c_row9_col9, #T_d904c_row10_col10, #T_d904c_row11_col11, #T_d904c_row12_col12, #T_d904c_row13_col13, #T_d904c_row14_col14, #T_d904c_row15_col15, #T_d904c_row16_col16, #T_d904c_row17_col17, #T_d904c_row18_col18, #T_d904c_row19_col19, #T_d904c_row20_col20, #T_d904c_row21_col21, #T_d904c_row22_col22, #T_d904c_row23_col23, #T_d904c_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d904c_row0_col1, #T_d904c_row0_col2, #T_d904c_row0_col3, #T_d904c_row0_col4, #T_d904c_row0_col6, #T_d904c_row0_col7, #T_d904c_row0_col9, #T_d904c_row0_col10, #T_d904c_row0_col11, #T_d904c_row0_col12, #T_d904c_row0_col13, #T_d904c_row0_col14, #T_d904c_row0_col16, #T_d904c_row0_col17, #T_d904c_row0_col19, #T_d904c_row0_col20, #T_d904c_row0_col24, #T_d904c_row2_col0, #T_d904c_row13_col21, #T_d904c_row14_col0, #T_d904c_row18_col5, #T_d904c_row18_col8, #T_d904c_row18_col22, #T_d904c_row21_col15, #T_d904c_row21_col23, #T_d904c_row22_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d904c_row0_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_d904c_row0_col8, #T_d904c_row4_col15 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_d904c_row0_col15, #T_d904c_row1_col15 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_d904c_row0_col18 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d904c_row0_col21, #T_d904c_row7_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d904c_row0_col22 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_d904c_row0_col23 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col2, #T_d904c_row10_col24, #T_d904c_row17_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col4, #T_d904c_row3_col1, #T_d904c_row4_col1, #T_d904c_row9_col10 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col5, #T_d904c_row6_col23 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_d904c_row1_col6, #T_d904c_row6_col7, #T_d904c_row20_col2, #T_d904c_row23_col11 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_d904c_row1_col7, #T_d904c_row7_col14, #T_d904c_row10_col8, #T_d904c_row10_col23, #T_d904c_row11_col8, #T_d904c_row17_col9 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col8, #T_d904c_row2_col13, #T_d904c_row12_col22, #T_d904c_row22_col16 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_d904c_row1_col9, #T_d904c_row4_col13, #T_d904c_row6_col14, #T_d904c_row8_col3, #T_d904c_row8_col4, #T_d904c_row17_col8, #T_d904c_row19_col20, #T_d904c_row23_col1, #T_d904c_row23_col4 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_d904c_row1_col10, #T_d904c_row2_col4, #T_d904c_row10_col4, #T_d904c_row12_col19, #T_d904c_row16_col10, #T_d904c_row19_col12 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col11, #T_d904c_row10_col2, #T_d904c_row10_col20, #T_d904c_row24_col8 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col12, #T_d904c_row3_col12, #T_d904c_row16_col4, #T_d904c_row17_col1, #T_d904c_row17_col16, #T_d904c_row22_col23 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col13, #T_d904c_row5_col17, #T_d904c_row7_col20, #T_d904c_row8_col5 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_d904c_row1_col14, #T_d904c_row3_col16, #T_d904c_row10_col12, #T_d904c_row10_col17, #T_d904c_row12_col4, #T_d904c_row14_col1, #T_d904c_row16_col3, #T_d904c_row16_col17, #T_d904c_row17_col3 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col16, #T_d904c_row16_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col17, #T_d904c_row4_col12, #T_d904c_row12_col10, #T_d904c_row17_col10 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col18, #T_d904c_row11_col0, #T_d904c_row13_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_d904c_row1_col19, #T_d904c_row4_col14, #T_d904c_row7_col12, #T_d904c_row10_col16, #T_d904c_row12_col7, #T_d904c_row12_col14, #T_d904c_row14_col16, #T_d904c_row14_col19, #T_d904c_row16_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col20, #T_d904c_row3_col20, #T_d904c_row19_col9, #T_d904c_row19_col11 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_d904c_row1_col21 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d904c_row1_col22, #T_d904c_row4_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_d904c_row1_col23, #T_d904c_row22_col7 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_d904c_row1_col24, #T_d904c_row3_col24, #T_d904c_row11_col3, #T_d904c_row20_col16 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col1, #T_d904c_row3_col19, #T_d904c_row11_col10 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col3, #T_d904c_row3_col2 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_d904c_row2_col6, #T_d904c_row22_col11 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_d904c_row2_col7, #T_d904c_row22_col10 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_d904c_row2_col8, #T_d904c_row15_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_d904c_row2_col9 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_d904c_row2_col10, #T_d904c_row5_col9, #T_d904c_row11_col20, #T_d904c_row13_col3, #T_d904c_row20_col9, #T_d904c_row20_col11 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col11, #T_d904c_row5_col12, #T_d904c_row14_col13, #T_d904c_row22_col3 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_d904c_row2_col12, #T_d904c_row7_col3, #T_d904c_row8_col11, #T_d904c_row11_col4, #T_d904c_row19_col10, #T_d904c_row24_col16 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col14, #T_d904c_row14_col2 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col15, #T_d904c_row4_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col16, #T_d904c_row9_col24, #T_d904c_row10_col1, #T_d904c_row14_col4 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col17, #T_d904c_row13_col17, #T_d904c_row20_col10, #T_d904c_row24_col20 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col18, #T_d904c_row15_col5, #T_d904c_row21_col12 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d904c_row2_col19 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col20, #T_d904c_row6_col20, #T_d904c_row20_col6 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_d904c_row2_col21, #T_d904c_row15_col6, #T_d904c_row21_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_d904c_row2_col22 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d904c_row2_col23 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_d904c_row2_col24, #T_d904c_row8_col19, #T_d904c_row20_col8 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_d904c_row3_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d904c_row3_col4, #T_d904c_row3_col17, #T_d904c_row4_col3, #T_d904c_row19_col3, #T_d904c_row24_col10 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_d904c_row3_col5 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_d904c_row3_col6, #T_d904c_row8_col6, #T_d904c_row12_col23, #T_d904c_row24_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_d904c_row3_col7, #T_d904c_row7_col10, #T_d904c_row12_col13, #T_d904c_row20_col24 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_d904c_row3_col8 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_d904c_row3_col9, #T_d904c_row5_col10, #T_d904c_row8_col16 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_d904c_row3_col10, #T_d904c_row4_col19, #T_d904c_row11_col24, #T_d904c_row12_col2 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_d904c_r

# %%
from sklearn.decomposition import PCA
pca = PCA()
dataset = pd.DataFrame()
transformed = pca.fit_transform(temp.drop('ni',axis=1))
for i in range(0, len(transformed[0])):
    dataset[i] = transformed[:,i]
    print(i, temp['ni'].corr(dataset[i]))
# Out:
# 0 0.3990354606611766
# 1 -0.1189586475859518
# 2 0.5291868432975254
# 3 -0.1895316562941621
# 4 -0.17439302627998157
# 5 0.19796631524298167
# 6 -0.40723797450216487
# 7 -0.44968172671493745
# 8 0.0611292624086065
# 9 -0.08681827921835131
# 10 -0.11107960130192128
# 11 -0.04489628796234607
# 12 0.03513671811833358
# 13 0.0808389635890443
# 14 0.0004245231808643108
# 15 0.032842334722462514
# 16 0.17148185074762715
# 17 -0.05543907813209585
# 18 0.008390132918850827
# 19 0.0025522096839458754
# 20 -0.03620127153343575
# 21 -0.022368305150012587
# 22 0.0010845767187404565
# 23 0.0006011918645396039

# %%
pca = PCA(n_components = 3)
transformed = pca.fit_transform(temp.drop('ni',axis=1))

# %%
print(pca.explained_variance_ratio_) #97% of the variance explained by first 3 principal components.
# Out:
# [0.92357055 0.04730212 0.01385517]

# %%
print(pca.singular_values_) #eigen values
# Out:
# [1189526.93976543  269202.7735291   145695.15826523]

# %%
dataset = pd.DataFrame({'Prin1': transformed[:, 0], 'Prin2': transformed[:, 1], 'Prin3': transformed[:, 2]})
print(dataset)
# Out:
#             Prin1        Prin2       Prin3
# 0    -5906.484803   958.351000  -42.643573
# 1    -6006.819820   998.955450  -49.066454
# 2    -6007.655826   977.085084  -57.663154
# 3    -6021.775848   979.575725  -64.778557
# 4    -5997.803502   986.549485  -50.303325
# ...           ...          ...         ...
# 2756 -4298.583743  1488.971211  333.519718
# 2757 -5288.675693  1436.409858   49.245693
# 2758 -5500.082946  1291.138139   -5.999447
# 2759 -5622.824256  1305.670640  138.573743
# 2760 -5475.247220  1223.915999  206.403309
#
# [2761 rows x 3 columns]

# %%
temp.corrwith(dataset.Prin1)
# Out:
# acominc   -0.677239
# act        0.965939
# ap         0.924104
# at         0.993791
# ch         0.919811
# citotal    0.386532
# cshpri     0.611385
# dltt       0.783393
# dvt        0.546951
# ebit       0.703202
# ebitda     0.857372
# gp         0.721390
# icapt      0.941859
# invt       0.662006
# lt         0.969206
# opeps      0.020021
# revt       0.944854
# seq        0.928322
# txdi       0.038106
# txp        0.892343
# txt        0.661361
# sic       -0.018980
# ni         0.399035
# pi         0.566840
# txpd       0.770922
# dtype: float64

# %%
temp.corrwith(dataset.Prin2)
# Out:
# acominc   -0.168868
# act       -0.138164
# ap         0.186494
# at         0.102344
# ch        -0.174127
# citotal   -0.115988
# cshpri    -0.358644
# dltt      -0.231912
# dvt       -0.366479
# ebit      -0.288037
# ebitda    -0.298008
# gp        -0.584552
# icapt     -0.245149
# invt      -0.375546
# lt         0.241307
# opeps     -0.060070
# revt      -0.283050
# seq       -0.260751
# txdi       0.018953
# txp        0.023910
# txt       -0.250457
# sic        0.072546
# ni        -0.118959
# pi        -0.163794
# txpd      -0.283755
# dtype: float64

# %%
temp.corrwith(dataset.Prin3)
# Out:
# acominc    0.492335
# act       -0.113539
# ap        -0.178376
# at         0.039525
# ch        -0.031199
# citotal    0.508668
# cshpri     0.078427
# dltt       0.203325
# dvt        0.458799
# ebit       0.438537
# ebitda     0.265804
# gp         0.197592
# icapt      0.211047
# invt       0.324774
# lt        -0.031346
# opeps      0.018307
# revt      -0.158123
# seq        0.224395
# txdi      -0.170925
# txp        0.043244
# txt        0.210612
# sic       -0.190738
# ni         0.529187
# pi         0.504566
# txpd       0.334435
# dtype: float64

# %%
data.columns
# Out:
# Index(['gvkey', 'datadate', 'fyear', 'tic', 'conm', 'fyr', 'fdate', 'acominc',
#        'act', 'ap', 'at', 'ch', 'citotal', 'cshpri', 'dltt', 'dvt', 'ebit',
#        'ebitda', 'gp', 'icapt', 'invt', 'lt', 'opeps', 'revt', 'seq', 'teq',
#        'txdba', 'txdbca', 'txdbcl', 'txdi', 'txp', 'txt', 'sic', 'spcindcd',
#        'spcseccd', 'ni', 'pi', 'txpd'],
#       dtype='object')
