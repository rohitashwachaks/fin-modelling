# %%
import pandas as pd
import numpy as np

# %%
fallen_angels = pd.read_csv('fallen_angels.csv')

# %%
gvkey2cik = pd.read_csv('gvkey2cik.csv')
gvkey2cik
# Out:
#         gvkey                         conm   DATADATE1   DATADATE2      cik  \
# 0        1002                     AAI CORP  12/31/1968  12/31/1972  1306124
# 1        1004                     AAR CORP  05/31/1966  05/31/2020     1750
# 2        1009           ABS INDUSTRIES INC  10/31/1981  10/31/1994   313368
# 3        1010           ACF INDUSTRIES INC  04/30/1951  12/31/2003     2036
# 4        1010           ACF INDUSTRIES INC  04/30/1951  12/31/2003   910627
# ...       ...                          ...         ...         ...      ...
# 34289  335466  HERMITAGE OFFSHORE SERVICES  12/31/2015  12/31/2019  1597659
# 34290  338640              TPG TELECOM LTD         NaN         NaN  1641424
# 34291  339015            METSO OUTOTEC OYJ         NaN         NaN  1436786
# 34292  339965                SNOWFLAKE INC  01/31/2019  01/31/2020  1640147
# 34293  343812                       TIM SA         NaN         NaN  1826168
#
# ...

# %%
gvkey2cik[gvkey2cik['cik'] == 924901]
# Out:
#        gvkey                   conm   DATADATE1   DATADATE2     cik SOURCE  \
# 14499  30637  MACK-CALI REALTY CORP  12/31/1993  12/31/2019  924901  COMPN
#
#                       coname      FNDATE      LNDATE  N10K  N10K_NT  N10K_A  \
# 14499  MACK CALI REALTY CORP  02/09/1995  11/04/2020    29        0       5
#
#        N10Q  N10Q_NT  N10Q_A  NDEF  N8K  NTOT  FLAG
# 14499    76        0       1    61  312  2186     3
